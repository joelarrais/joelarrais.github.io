# %%
# !git clone https://github.com/pgmpy/pgmpy_notebook.git
# Out:
# Cloning into 'pgmpy_notebook'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 366 (delta 43), reused 65 (delta 43), pack-reused 294
# Receiving objects: 100% (366/366), 2.82 MiB | 21.88 MiB/s, done.
# Resolving deltas: 100% (198/198), done.
